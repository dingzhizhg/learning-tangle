# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# 设置字体

# 假设你有两组数据，每组数据是一个字典列表，记录了每10轮的准确率
data_group_1 = [
    {'accuracy': 0.02139013550453855, 'loss': 4.122910935514972, 'consensus_round': 0.0, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.08500485823186124, 'loss': 3.6917732832631214, 'consensus_round': 9.0, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.18627387515552354, 'loss': 3.6543749322512316, 'consensus_round': 17.666666666666668, 'consensus_poisoning': 0.0, 'norm': 0.5415457487106323},
    {'accuracy': 0.5047615415556852, 'loss': 2.0995560543283034, 'consensus_round': 28.333333333333336, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.5796188960032813, 'loss': 1.6160641760853551, 'consensus_round': 38.66666666666667, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.5622104303042869, 'loss': 1.579255400804531, 'consensus_round': 48.333333333333336, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.6523760203582158, 'loss': 1.1754263460210899, 'consensus_round': 57.66666666666667, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.6709958698247358, 'loss': 1.1420180094146293, 'consensus_round': 67.33333333333331, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.6843073239720655, 'loss': 1.0877956698863804, 'consensus_round': 78.33333333333331, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.7319418497914989, 'loss': 0.8872500202466567, 'consensus_round': 88.66666666666664, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.6962296930733604, 'loss': 0.9203552583518819, 'consensus_round': 98.66666666666667, 'consensus_poisoning': 0.0, 'norm': 0.0}
]

data_group_2 = [
    {'accuracy': 0.0036987402841061378, 'loss': 4.135044975531258, 'consensus_round': 0.0, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.06528241806710408, 'loss': 3.771758901180077, 'consensus_round': 5.076923076923077, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.09211253080955988, 'loss': 3.6176780009493, 'consensus_round': 11.749746791536593, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.41330000444812434, 'loss': 3.2567365974540543, 'consensus_round': 22.434881656804734, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.604144299840062, 'loss': 1.6861757268615094, 'consensus_round': 31.363491039426524, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.5902837833127212, 'loss': 1.5437465916045858, 'consensus_round': 41.063615506329114, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.702828556008151, 'loss': 1.026346878404842, 'consensus_round': 51.6, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.7047392330390705, 'loss': 1.0098024211465355, 'consensus_round': 58.977473262032085, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.7658915691746271, 'loss': 0.8244983889347266, 'consensus_round': 66.90835537190081, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.816862252126958, 'loss': 0.6207980987789866, 'consensus_round': 79.3974945054945, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.8101291842458977, 'loss': 0.6197246590401205, 'consensus_round': 88.3311970159376, 'consensus_poisoning': 0.0, 'norm': 0.0}
]

data_group_3 = [
    {'accuracy': 0.02139013550453855, 'loss': 4.122910935514972, 'consensus_round': 0.0, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.08360651548977056, 'loss': 3.6836783498940395, 'consensus_round': 9.0, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.11952001559480868, 'loss': 3.7680705697956407, 'consensus_round': 17.666666666666668, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.5324005412822589, 'loss': 1.9377879623528182, 'consensus_round': 28.666666666666664, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.5575223929560369, 'loss': 1.6682929804791575, 'consensus_round': 39.33333333333333, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.5824297794393744, 'loss': 1.5079887756097208, 'consensus_round': 48.666666666666664, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.6922805016477963, 'loss': 1.0818339222074265, 'consensus_round': 58.66666666666667, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.6987976478977934, 'loss': 1.0568264423120761, 'consensus_round': 68.33333333333331, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.6911529847480498, 'loss': 1.0567298020992, 'consensus_round': 78.0, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.7357204715859332, 'loss': 0.8771142376514705, 'consensus_round': 88.66666666666664, 'consensus_poisoning': 0.0, 'norm': 0.0},
    {'accuracy': 0.6866520611523149, 'loss': 0.9386031882772399, 'consensus_round': 98.66666666666667, 'consensus_poisoning': 0.0, 'norm': 0.0}
]

# 提取每组数据中的准确率
accuracy_group_1 = [d['accuracy'] for d in data_group_1]
accuracy_group_2 = [d['accuracy'] for d in data_group_2]
accuracy_group_3 = [d['accuracy'] for d in data_group_3]

# 横坐标为轮数（以10为单位）
rounds = list(range(0, 110, 10))

# 创建图形
plt.figure(figsize=(5,3))

# 生成 4 种颜色的线条
colors = plt.cm.viridis(np.linspace(0, 3, 6))  
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=colors)


# 绘制第一组数据
plt.plot(rounds, accuracy_group_1, label='Con-DAG, λ=0.3', marker='o')

# 绘制第二组数据
plt.plot(rounds, accuracy_group_2, label='Con-DAG, λ=0.5', marker='s',color='darkorange')

# 绘制第三组数据
plt.plot(rounds, accuracy_group_3, label='Con-DAG, λ=0.7', marker='^')

# 设置标题和坐标轴标签
plt.xlabel('Rounds')
plt.ylabel('Accuracy')

# 设置图例位置为右下角
plt.legend(loc='lower right')

# 显示图形
plt.show()
